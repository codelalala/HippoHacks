# %%
from pandas import DataFrame, read_csv

# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number

# Enable inline plotting
# %matplotlib inline

# %%
ls
# Out:
#  Volume in drive C is Local Disk
#  Volume Serial Number is D079-03A9
#
#  Directory of C:\Users\yangc\Documents\python\Hippo\2014
#
# 04/08/2017  04:34 AM    <DIR>          .
# 04/08/2017  04:34 AM    <DIR>          ..
# 04/08/2017  04:33 AM    <DIR>          .ipynb_checkpoints
# 04/08/2017  04:31 AM            63,127 assistance.csv
# 04/08/2017  04:34 AM             1,757 Fundling2014.ipynb
# 04/08/2017  04:31 AM         1,405,180 subaward.csv
#                3 File(s)      1,470,064 bytes
#                3 Dir(s)  363,391,348,736 bytes free

# %%
location=r'C:/Users/yangc/Documents/python/Hippo/2015/assistance2015.csv'
#df = pd.read_csv(location,dtype={'ALL_MTH00NUMVALID_1415':str,'ALL_MTH00PCTPROF_1415':str})
df = pd.read_csv(location)

# %%
df.head(1)
# Out:
#    total_funding_amount principal_place_state  fiscal_year
# 0              -2826542               FLORIDA         2015

# %%
ass15=df.groupby(['principal_place_state']).sum()

# %%
location=r'C:/Users/yangc/Documents/python/Hippo/2015/assistance2015.csv'
#df = pd.read_csv(location,dtype={'ALL_MTH00NUMVALID_1415':str,'ALL_MTH00PCTPROF_1415':str})
df = pd.read_csv(location)
ass15=df.groupby(['principal_place_state']).sum()
ass15.to_excel('ass15.xlsx')
ass15=pd.read_excel('ass15.xlsx')
ass15=ass15.set_index(['principal_place_state'])

ass14
location=r'C:/Users/yangc/Documents/python/Hippo/2014/assistance2014.csv'
#df = pd.read_csv(location,dtype={'ALL_MTH00NUMVALID_1415':str,'ALL_MTH00PCTPROF_1415':str})
df = pd.read_csv(location)
ass14=df.groupby(['principal_place_state']).sum()
ass14.to_excel('ass14.xlsx')
ass14=pd.read_excel('ass14.xlsx')
ass14=ass14.set_index(['principal_place_state'])


ass13
location=r'C:/Users/yangc/Documents/python/Hippo/2013/assistance2013.csv'
#df = pd.read_csv(location,dtype={'ALL_MTH00NUMVALID_1415':str,'ALL_MTH00PCTPROF_1415':str})
df = pd.read_csv(location)
ass13=df.groupby(['principal_place_state']).sum()
ass13.to_excel('ass13.xlsx')
ass13=pd.read_excel('ass13.xlsx')
ass13=ass13.set_index(['principal_place_state'])


ass14
# Out:
#                        total_funding_amount  fiscal_year
# principal_place_state
# ALABAMA                             2563301         2014
# ALASKA                               744842         2014
# ARIZONA                             1635511         6042
# ARKANSAS                            1638892         2014
# CALIFORNIA                         18410701         2014
# COLORADO                            1823481         2014
# CONNECTICUT                          968458         4028
# DELAWARE                             684007         6042
# DISTRICTOFCOLUMBIA                   693044         4028
# FLORIDA                             7424860         4028
# GEORGIA                             5563291         4028
# HAWAII                               744842         2014
# IDAHO                                744842         2014
# ILLINOIS                            5226170         2014
# INDIANA                             2673251         6042
# ...

# %%
ass15
# Out:
#                            total_funding_amount  fiscal_year
# principal_place_state
# ALABAMA                                 2594282         2015
# ALASKA                                   759767         2015
# ARIZONA                                 3665701         2015
# ARKANSAS                                1681918         2015
# CALIFORNIA                             18584702         2015
# COLORADO                                1763673         2015
# CONNECTICUT                              985653         2015
# DELAWARE                                 759767         2015
# DISTRICT OF COLUMBIA                     759767         2015
# FLORIDA                                -2826542         2015
# FLORIDA                                 8579427         2015
# GEORGIA                                 5638551         2015
# HAWAII                                   759767         2015
# IDAHO                                    759767         2015
# ...

# %%
location=r'C:/Users/yangc/Documents/python/Hippo/2013/subaward2013.csv'
#df = pd.read_csv(location,dtype={'ALL_MTH00NUMVALID_1415':str,'ALL_MTH00PCTPROF_1415':str})
df = pd.read_csv(location)
df.head(1)
sub13=df.groupby(['prime_award_principal_place_state']).sum()

location=r'C:/Users/yangc/Documents/python/Hippo/2014/subaward2014.csv'
#df = pd.read_csv(location,dtype={'ALL_MTH00NUMVALID_1415':str,'ALL_MTH00PCTPROF_1415':str})
df = pd.read_csv(location)
df.head(1)
sub14=df.groupby(['prime_award_principal_place_state']).sum()

location=r'C:/Users/yangc/Documents/python/Hippo/2015/subaward2015.csv'
#df = pd.read_csv(location,dtype={'ALL_MTH00NUMVALID_1415':str,'ALL_MTH00PCTPROF_1415':str})
df = pd.read_csv(location)
df.head(1)
sub15=df.groupby(['prime_award_principal_place_state']).sum()

# %%
pd.concat([sub13,sub14,sub15],axis=1,join='inner')
# Out:
#                                    prime_award_amount  \
# prime_award_principal_place_state
# FL                                          203006700
# MA                                            5121948
#
#                                    prime_award_fiscal_year  \
# prime_award_principal_place_state
# FL                                                   50300
# MA                                                    6036
#
#                                    prime_award_amount  \
# prime_award_principal_place_state
# FL                                          196555150
# MA                                           61222214
#
#                                    prime_award_fiscal_year  \
# prime_award_principal_place_state
# FL                                                   50325
# MA                                                   72449
#
#                                    prime_award_amount  prime_award_fiscal_year
# prime_award_principal_place_state
# ...

# %%
a=pd.concat([ass13,ass14,ass15],axis=1)
a.to_excel('fund.xlsx')
