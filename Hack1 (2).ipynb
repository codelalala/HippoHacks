# %%
import pandas as pd
pd.set_option('display.mpl_style','default')

# %%
Math_par_1415_all=pd.read_csv('D:\Hackerthon\math-participation-sch-sy2014-15All.csv')

# %%
Math_par_1415_all[1:3]
# Out:
#     STNAM  FI0T     AID                              ANM      NCESSCH  \
# 1  ALASKA     2  200001  Lower Kuskokwim School District  20000100207
# 2  ALASKA     2  200001  Lower Kuskokwim School District  20000100208
#
#                         SCHNAM   DATE_CUR  ALL_MTH00NUMPART_1415  \
# 1         Gladys Jung Ementary  13-Apr-16                    324
# 2  Bethel Regional High School  13-Apr-16                    336
#
#   ALL_MTH00PCTPART_1415  ALL_MTH00NUMPART_1415_eff MAM_MTH00NUMPART_1415  \
# 1                    99                     320.76                   272
# 2                    97                     325.92                   291
#
#   MAM_MTH00PCTPART_1415  MAM_MTH00NUMPART_1415_eff
# 1                    95                        NaN
# 2                    95                        NaN

# %%
Math_par_1415_all['ALL_MTH00NUMPART_1415'].plot(figsize=(15,10))

# %%
import matplotlib.pyplot as plt

# %%
import sys

# %%
import matplotlib

# %%
# %matplotlib inline

# %%
Math_par_1314_all.groupby('STNAM')['ALL_MTH00NUMPART_1314'].sum()
# Out:
# STNAM
# ALASKA                    73545
# ARIZONA                  579405
# ARKANSAS                 274726
# CALIFORNIA              3146556
# COLORADO                 447668
# CONNECTICUT              268256
# DELAWARE                  68760
# DISTRICT OF COLUMBIA      31689
# FLORIDA                 1636907
# HAWAII                    93521
# IDAHO                    151913
# ILLINOIS                 985971
# INDIANA                  540521
# IOWA                     248575
# KANSAS                   240912
# KENTUCKY                 348205
# LOUISIANA                359497
# MAINE                     83106
# MARYLAND                 436998
# MASSACHUSETTS            488484
# MICHIGAN                 776119
# MINNESOTA                437610
# MISSISSIPPI              260690
# MISSOURI                 458583
# MONTANA                   61959
# NEBRASKA                 158800
# NEW HAM0HIRE              91726
# NEW JERSEY               751495
# NEW MEXICO               203173
# ...

# %%
Math_par_1415_all.groupby('STNAM')['ALL_MTH00NUMPART_1415_eff'].sum().head(10).plot(figsize=(15,10))

# %%
from pandas import DataFrame, read_csv

# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number

# Enable inline plotting
# %matplotlib inline

# %%
Math_par_1415_all.tail(1000)
# Out:
#          STNAM  FI0T      AID                                   ANM  \
# 0       ALASKA     2   200001       Lower Kuskokwim School District
# 1       ALASKA     2   200001       Lower Kuskokwim School District
# 2       ALASKA     2   200001       Lower Kuskokwim School District
# 3       ALASKA     2   200001       Lower Kuskokwim School District
# 4       ALASKA     2   200001       Lower Kuskokwim School District
# 5       ALASKA     2   200001       Lower Kuskokwim School District
# 6       ALASKA     2   200001       Lower Kuskokwim School District
# 7       ALASKA     2   200001       Lower Kuskokwim School District
# 8       ALASKA     2   200001       Lower Kuskokwim School District
# 9       ALASKA     2   200001       Lower Kuskokwim School District
# 10      ALASKA     2   200001       Lower Kuskokwim School District
# 11      ALASKA     2   200001       Lower Kuskokwim School District
# 12      ALASKA     2   200001       Lower Kuskokwim School District
# ...

# %%
def s(data):
    if(data.find('GE'))==0:
        data=data[2:4]
        #print(data)
    if(data.find('LT'))==0:
        data=str(int(data[2:4])-1)
    if(data.find('LE'))==0:
        data=data[2:4]
    if(data.find('GT'))==0:
        data=str(int(data[2:4])+1)
    if(data.find('-'))==2:
        #print(data[0:2],data[3:5],int((int(data[0:2])+int(data[3:5]))/2))
        data=str(int((int(data[0:2])+int(data[3:5]))/2))
    return data

# %%
if(clean_data.ALL_MTH00PCTPART_1415('-'))==2:
    clean_data.ALL_MTH00PCTPART_1415=str((int((int(clean_data.ALL_MTH00PCTPART_1415[0:2])+int(clean_data.ALL_MTH00PCTPART_1415[3:5]))/2)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-8f41ab75f864> in <module>()
# ----> 1 if(clean_data.ALL_MTH00PCTPART_1415('-'))==2:
#       2     clean_data.ALL_MTH00PCTPART_1415=str((int((int(clean_data.ALL_MTH00PCTPART_1415[0:2])+int(clean_data.ALL_MTH00PCTPART_1415[3:5]))/2)))
#
# TypeError: 'Series' object is not callable

# %%
clean_data.ALL_MTH00PCTPART_1415=clean_data.ALL_MTH00PCTPART_1415.apply(s)
clean_data.head(100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-583da78ed9f0> in <module>()
#       1
# ----> 2 clean_data.ALL_MTH00PCTPART_1415=clean_data.ALL_MTH00PCTPART_1415.apply(s)
#       3 clean_data.head(100)
#
# C:\Users\ellaT430s\Anaconda2\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2158             values = lib.map_infer(values, lib.Timestamp)
#    2159
# -> 2160         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2161         if len(mapped) and isinstance(mapped[0], Series):
#    2162             from pandas.core.frame import DataFrame
#
# pandas\src\inference.pyx in pandas.lib.map_infer (pandas\lib.c:62187)()
#
# <ipython-input-89-bfd1458a75e6> in s(data)
#      12     if(data.find('-'))==2:
#      13         #print(data[0:2],data[3:5],int((int(data[0:2])+int(data[3:5]))/2))
# ...

# %%
clean_data=Math_par_1415_all.ALL_MTH00PCTPART_1415

# %%
while i<
clean_data[2:5].apply(s)
# Out:
# 2    97
# 3    95
# 4    95
# Name: ALL_MTH00PCTPART_1415, dtype: object
